# %%
#!/usr/bin/python

# Import required modules
import os
import sys
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
import matplotlib.ticker as mpltkr
import matplotlib.colors as mplcolors
import matplotlib.patches as mplpatches
from mpl_toolkits.mplot3d import Axes3D
from scipy.stats import gaussian_kde

# Import COSMO style toolkit
import COSMOplot.colorbars as cosmocbars
import COSMOplot.colors as cosmocolors
import COSMOplot.cycles as cosmocycles
import COSMOplot.style as cosmostyle
import COSMOplot.utils as cosmoutils

cosmostyle.set_style('article')
colorList = cosmocycles.color_cycle

# %% [markdown]
# # Distance Histograms

# %%
# Load FPS-selected DEEM and IZA histograms, 3.5 A SOAP cutoff

distDD = np.loadtxt('../Processed_Data/DEEM_1k/Histograms/3.5/FPS/distAA.hist', unpack=True)
distII = np.loadtxt('../Processed_Data/DEEM_1k/Histograms/3.5/FPS/distBB.hist', unpack=True)
distDI = np.loadtxt('../Processed_Data/DEEM_1k/Histograms/3.5/FPS/distAB.hist', unpack=True)

minDistDD = np.loadtxt('../Processed_Data/DEEM_1k/Histograms/3.5/FPS/minDistAA.hist', unpack=True)
minDistDI = np.loadtxt('../Processed_Data/DEEM_1k/Histograms/3.5/FPS/minDistAB.hist', unpack=True)
minDistID = np.loadtxt('../Processed_Data/DEEM_1k/Histograms/3.5/FPS/minDistBA.hist', unpack=True)

figHist = plt.figure(figsize=(3.54, 3.54))
axsDist = figHist.add_subplot(2, 1, 1)
axsMinDist = figHist.add_subplot(2, 1, 2)

for i in [axsDist, axsMinDist]:
    i.set_ylabel('Frequency')
    
axsMinDist.set_xlabel('Distance')
axsDist.set_ylim([0.0, 15.0])
axsDist.set_xlim([0.01, 1.0])
axsMinDist.set_ylim([0.0, 125.0])
axsMinDist.set_xlim([0.01, 1.0])
axsMinDist.set_xscale('log')
axsDist.set_xscale('log')

axsDist.plot(distDD[0], distDD[1], label='DEEM-DEEM')
axsDist.plot(distII[0], distII[1], label='IZA-IZA')
axsDist.plot(distDI[0], distDI[1], label='DEEM-IZA')
axsDist.fill_between(distDD[0], distDD[1], alpha=0.2)
axsDist.fill_between(distII[0], distII[1], alpha=0.2)
axsDist.fill_between(distDI[0], distDI[1], alpha=0.2)
axsDist.text(0.05, 0.95, u'3.5 \u00c5,\nDistance', horizontalalignment='left', verticalalignment='top', 
             transform=axsDist.transAxes, fontsize='medium')

axsMinDist.plot(minDistDD[0], minDistDD[1], label='DEEM-DEEM')
axsMinDist.plot(minDistDI[0], minDistDI[1], label='DEEM-IZA')
axsMinDist.plot(minDistID[0], minDistID[1], label='IZA-DEEM')
axsMinDist.fill_between(minDistDD[0], minDistDD[1], alpha=0.2)
axsMinDist.fill_between(minDistDI[0], minDistDI[1], alpha=0.2)
axsMinDist.fill_between(minDistID[0], minDistID[1], alpha=0.2)
axsMinDist.text(0.05, 0.95, u'3.5 \u00c5, \nMinimum\nDistance', horizontalalignment='left', verticalalignment='top', 
                transform=axsMinDist.transAxes, fontsize='medium')


axsDist.legend(frameon=False)
axsMinDist.legend(frameon=False)

figHist.savefig('../Results/DEEM_1k/distances_3.5_FPS.pdf', bbox_inches='tight')
plt.show()

# %%
# Load FPS-selected DEEM and IZA histograms, 3.5 A SOAP cutoff

distDD = np.loadtxt('../Processed_Data/DEEM_10k/Histograms/3.5/FPS/distAA.hist', unpack=True)
distII = np.loadtxt('../Processed_Data/DEEM_10k/Histograms/3.5/FPS/distBB.hist', unpack=True)
distDI = np.loadtxt('../Processed_Data/DEEM_10k/Histograms/3.5/FPS/distAB.hist', unpack=True)

minDistDD = np.loadtxt('../Processed_Data/DEEM_10k/Histograms/3.5/FPS/minDistAA.hist', unpack=True)
minDistDI = np.loadtxt('../Processed_Data/DEEM_10k/Histograms/3.5/FPS/minDistAB.hist', unpack=True)
minDistID = np.loadtxt('../Processed_Data/DEEM_10k/Histograms/3.5/FPS/minDistBA.hist', unpack=True)

figHist = plt.figure(figsize=(3.54, 3.54))
axsDist = figHist.add_subplot(2, 1, 1)
axsMinDist = figHist.add_subplot(2, 1, 2)

for i in [axsDist, axsMinDist]:
    i.set_ylabel('Frequency')
    
axsMinDist.set_xlabel('Distance')
axsDist.set_ylim([0.0, 15.0])
axsDist.set_xlim([0.01, 1.0])
axsMinDist.set_ylim([0.0, 125.0])
axsMinDist.set_xlim([0.01, 1.0])
axsMinDist.set_xscale('log')
axsDist.set_xscale('log')

axsDist.plot(distDD[0], distDD[1], label='DEEM-DEEM')
axsDist.plot(distII[0], distII[1], label='IZA-IZA')
axsDist.plot(distDI[0], distDI[1], label='DEEM-IZA')
axsDist.fill_between(distDD[0], distDD[1], alpha=0.2)
axsDist.fill_between(distII[0], distII[1], alpha=0.2)
axsDist.fill_between(distDI[0], distDI[1], alpha=0.2)
axsDist.text(0.05, 0.95, u'3.5 \u00c5,\nDistance', horizontalalignment='left', verticalalignment='top', 
             transform=axsDist.transAxes, fontsize='medium')

axsMinDist.plot(minDistDD[0], minDistDD[1], label='DEEM-DEEM')
axsMinDist.plot(minDistDI[0], minDistDI[1], label='DEEM-IZA')
axsMinDist.plot(minDistID[0], minDistID[1], label='IZA-DEEM')
axsMinDist.fill_between(minDistDD[0], minDistDD[1], alpha=0.2)
axsMinDist.fill_between(minDistDI[0], minDistDI[1], alpha=0.2)
axsMinDist.fill_between(minDistID[0], minDistID[1], alpha=0.2)
axsMinDist.text(0.95, 0.05, u'3.5 \u00c5, \nMinimum\nDistance', horizontalalignment='right', verticalalignment='bottom', 
                transform=axsMinDist.transAxes, fontsize='medium')


axsDist.legend(frameon=False)
axsMinDist.legend(frameon=False)

figHist.savefig('../Results/DEEM_10k/distances_3.5_FPS.pdf', bbox_inches='tight')
plt.show()

# %%
# Load FPS-selected DEEM and IZA histograms, 6.0 A SOAP cutoff

distDD = np.loadtxt('../Processed_Data/DEEM_1k/Histograms/6.0/FPS/distAA.hist', unpack=True)
distII = np.loadtxt('../Processed_Data/DEEM_1k/Histograms/6.0/FPS/distBB.hist', unpack=True)
distDI = np.loadtxt('../Processed_Data/DEEM_1k/Histograms/6.0/FPS/distAB.hist', unpack=True)

minDistDD = np.loadtxt('../Processed_Data/DEEM_1k/Histograms/6.0/FPS/minDistAA.hist', unpack=True)
minDistDI = np.loadtxt('../Processed_Data/DEEM_1k/Histograms/6.0/FPS/minDistAB.hist', unpack=True)
minDistID = np.loadtxt('../Processed_Data/DEEM_1k/Histograms/6.0/FPS/minDistBA.hist', unpack=True)

figHist = plt.figure(figsize=(3.54, 3.54))
axsDist = figHist.add_subplot(2, 1, 1)
axsMinDist = figHist.add_subplot(2, 1, 2)

for i in [axsDist, axsMinDist]:
    i.set_ylabel('Frequency')
    
axsMinDist.set_xlabel('Distance')
axsDist.set_ylim([0.0, 8.0])
axsDist.set_xlim([0.01, 1.0])
axsMinDist.set_ylim([0.0, 80.0])
axsMinDist.set_xlim([0.01, 1.0])
axsMinDist.set_xscale('log')
axsDist.set_xscale('log')

axsDist.plot(distDD[0], distDD[1], label='DEEM-DEEM')
axsDist.plot(distII[0], distII[1], label='IZA-IZA')
axsDist.plot(distDI[0], distDI[1], label='DEEM-IZA')
axsDist.fill_between(distDD[0], distDD[1], alpha=0.2)
axsDist.fill_between(distII[0], distII[1], alpha=0.2)
axsDist.fill_between(distDI[0], distDI[1], alpha=0.2)
axsDist.text(0.05, 0.05, u'6.0 \u00c5,\nDistance', horizontalalignment='left', verticalalignment='bottom', 
             transform=axsDist.transAxes, fontsize='medium')

axsMinDist.plot(minDistDD[0], minDistDD[1], label='DEEM-DEEM')
axsMinDist.plot(minDistDI[0], minDistDI[1], label='DEEM-IZA')
axsMinDist.plot(minDistID[0], minDistID[1], label='IZA-DEEM')
axsMinDist.fill_between(minDistDD[0], minDistDD[1], alpha=0.2)
axsMinDist.fill_between(minDistDI[0], minDistDI[1], alpha=0.2)
axsMinDist.fill_between(minDistID[0], minDistID[1], alpha=0.2)
axsMinDist.text(0.05, 0.05, u'6.0 \u00c5, \nMinimum Distance', horizontalalignment='left', verticalalignment='bottom', 
                transform=axsMinDist.transAxes, fontsize='medium')


axsDist.legend(frameon=False)
axsMinDist.legend(frameon=False)

figHist.savefig('../Results/DEEM_1k/distances_6.0_FPS.pdf', bbox_inches='tight')
plt.show()

# %%
# Load FPS-selected DEEM and IZA histograms, 6.0 A SOAP cutoff

distDD = np.loadtxt('../Processed_Data/DEEM_10k/Histograms/6.0/FPS/distAA.hist', unpack=True)
distII = np.loadtxt('../Processed_Data/DEEM_10k/Histograms/6.0/FPS/distBB.hist', unpack=True)
distDI = np.loadtxt('../Processed_Data/DEEM_10k/Histograms/6.0/FPS/distAB.hist', unpack=True)

minDistDD = np.loadtxt('../Processed_Data/DEEM_10k/Histograms/6.0/FPS/minDistAA.hist', unpack=True)
minDistDI = np.loadtxt('../Processed_Data/DEEM_10k/Histograms/6.0/FPS/minDistAB.hist', unpack=True)
minDistID = np.loadtxt('../Processed_Data/DEEM_10k/Histograms/6.0/FPS/minDistBA.hist', unpack=True)

figHist = plt.figure(figsize=(3.54, 3.54))
axsDist = figHist.add_subplot(2, 1, 1)
axsMinDist = figHist.add_subplot(2, 1, 2)

for i in [axsDist, axsMinDist]:
    i.set_ylabel('Frequency')
    
axsMinDist.set_xlabel('Distance')
axsDist.set_ylim([0.0, 8.0])
axsDist.set_xlim([0.01, 1.0])
axsMinDist.set_ylim([0.0, 80.0])
axsMinDist.set_xlim([0.01, 1.0])
axsMinDist.set_xscale('log')
axsDist.set_xscale('log')

axsDist.plot(distDD[0], distDD[1], label='DEEM-DEEM')
axsDist.plot(distII[0], distII[1], label='IZA-IZA')
axsDist.plot(distDI[0], distDI[1], label='DEEM-IZA')
axsDist.fill_between(distDD[0], distDD[1], alpha=0.2)
axsDist.fill_between(distII[0], distII[1], alpha=0.2)
axsDist.fill_between(distDI[0], distDI[1], alpha=0.2)
axsDist.text(0.05, 0.05, u'6.0 \u00c5,\nDistance', horizontalalignment='left', verticalalignment='bottom', 
             transform=axsDist.transAxes, fontsize='medium')

axsMinDist.plot(minDistDD[0], minDistDD[1], label='DEEM-DEEM')
axsMinDist.plot(minDistDI[0], minDistDI[1], label='DEEM-IZA')
axsMinDist.plot(minDistID[0], minDistID[1], label='IZA-DEEM')
axsMinDist.fill_between(minDistDD[0], minDistDD[1], alpha=0.2)
axsMinDist.fill_between(minDistDI[0], minDistDI[1], alpha=0.2)
axsMinDist.fill_between(minDistID[0], minDistID[1], alpha=0.2)
axsMinDist.text(0.05, 0.05, u'6.0 \u00c5, \nMinimum Distance', horizontalalignment='left', verticalalignment='bottom', 
                transform=axsMinDist.transAxes, fontsize='medium')


axsDist.legend(frameon=False)
axsMinDist.legend(frameon=False)

figHist.savefig('../Results/DEEM_10k/distances_6.0_FPS.pdf', bbox_inches='tight')
plt.show()

# %%
# Load randomly-selected DEEM and IZA histograms, 3.5 A SOAP cutoff

distDD = np.loadtxt('../Processed_Data/DEEM_1k/Histograms/3.5/Random/distAA.hist', unpack=True)
distII = np.loadtxt('../Processed_Data/DEEM_1k/Histograms/3.5/Random/distBB.hist', unpack=True)
distDI = np.loadtxt('../Processed_Data/DEEM_1k/Histograms/3.5/Random/distAB.hist', unpack=True)

minDistDD = np.loadtxt('../Processed_Data/DEEM_1k/Histograms/3.5/Random/minDistAA.hist', unpack=True)
minDistDI = np.loadtxt('../Processed_Data/DEEM_1k/Histograms/3.5/Random/minDistAB.hist', unpack=True)
minDistID = np.loadtxt('../Processed_Data/DEEM_1k/Histograms/3.5/Random/minDistBA.hist', unpack=True)

figHist = plt.figure(figsize=(3.54, 3.54))
axsDist = figHist.add_subplot(2, 1, 1)
axsMinDist = figHist.add_subplot(2, 1, 2)

axsMinDist.set_xlabel('Distance')
axsDist.set_ylim([0.0, 15.0])
axsDist.set_xlim([0.001, 1.0])
axsMinDist.set_ylim([0.0, 125.0])
axsMinDist.set_xlim([0.001, 1.0])
axsMinDist.set_xscale('log')
axsDist.set_xscale('log')

axsDist.plot(distDD[0], distDD[1], label='DEEM-DEEM')
axsDist.plot(distII[0], distII[1], label='IZA-IZA')
axsDist.plot(distDI[0], distDI[1], label='DEEM-IZA')
axsDist.fill_between(distDD[0], distDD[1], alpha=0.2)
axsDist.fill_between(distII[0], distII[1], alpha=0.2)
axsDist.fill_between(distDI[0], distDI[1], alpha=0.2)
axsDist.text(0.05, 0.05, u'3.5 \u00c5,\nDistance', horizontalalignment='left', verticalalignment='bottom', 
             transform=axsDist.transAxes, fontsize='medium')

axsMinDist.plot(minDistDD[0], minDistDD[1], label='DEEM-DEEM')
axsMinDist.plot(minDistDI[0], minDistDI[1], label='DEEM-IZA')
axsMinDist.plot(minDistID[0], minDistID[1], label='IZA-DEEM')
axsMinDist.fill_between(minDistDD[0, 1:], minDistDD[1, 1:], alpha=0.2)
axsMinDist.fill_between(minDistDI[0], minDistDI[1], alpha=0.2)
axsMinDist.fill_between(minDistID[0], minDistID[1], alpha=0.2)
axsMinDist.text(0.05, 0.05, u'3.5 \u00c5, \nMinimum\nDistance', horizontalalignment='left', verticalalignment='bottom', 
                transform=axsMinDist.transAxes, fontsize='medium')


axsDist.legend(frameon=False)
axsMinDist.legend(frameon=False)

figHist.savefig('../Results/DEEM_1k/distances_3.5_random.pdf', bbox_inches='tight')
plt.show()

# %%
# Load randomly-selected DEEM and IZA histograms, 3.5 A SOAP cutoff

distDD = np.loadtxt('../Processed_Data/DEEM_10k/Histograms/3.5/Random/distAA.hist', unpack=True)
distII = np.loadtxt('../Processed_Data/DEEM_10k/Histograms/3.5/Random/distBB.hist', unpack=True)
distDI = np.loadtxt('../Processed_Data/DEEM_10k/Histograms/3.5/Random/distAB.hist', unpack=True)

minDistDD = np.loadtxt('../Processed_Data/DEEM_10k/Histograms/3.5/Random/minDistAA.hist', unpack=True)
minDistDI = np.loadtxt('../Processed_Data/DEEM_10k/Histograms/3.5/Random/minDistAB.hist', unpack=True)
minDistID = np.loadtxt('../Processed_Data/DEEM_10k/Histograms/3.5/Random/minDistBA.hist', unpack=True)

figHist = plt.figure(figsize=(3.54, 3.54))
axsDist = figHist.add_subplot(2, 1, 1)
axsMinDist = figHist.add_subplot(2, 1, 2)

for i in [axsDist, axsMinDist]:
    i.set_ylabel('Frequency')
    
axsMinDist.set_xlabel('Distance')
axsDist.set_ylim([0.0, 15.0])
axsDist.set_xlim([0.001, 1.0])
axsMinDist.set_ylim([0.0, 125.0])
axsMinDist.set_xlim([0.001, 1.0])
axsMinDist.set_xscale('log')
axsDist.set_xscale('log')

axsDist.plot(distDD[0], distDD[1], label='DEEM-DEEM')
axsDist.plot(distII[0], distII[1], label='IZA-IZA')
axsDist.plot(distDI[0], distDI[1], label='DEEM-IZA')
axsDist.fill_between(distDD[0], distDD[1], alpha=0.2)
axsDist.fill_between(distII[0], distII[1], alpha=0.2)
axsDist.fill_between(distDI[0], distDI[1], alpha=0.2)
axsDist.text(0.05, 0.05, u'3.5 \u00c5,\nDistance', horizontalalignment='left', verticalalignment='bottom', 
             transform=axsDist.transAxes, fontsize='medium')

axsMinDist.plot(minDistDD[0], minDistDD[1], label='DEEM-DEEM')
axsMinDist.plot(minDistDI[0], minDistDI[1], label='DEEM-IZA')
axsMinDist.plot(minDistID[0], minDistID[1], label='IZA-DEEM')
axsMinDist.fill_between(minDistDD[0, 1:], minDistDD[1, 1:], alpha=0.2)
axsMinDist.fill_between(minDistDI[0], minDistDI[1],  alpha=0.2)
axsMinDist.fill_between(minDistID[0], minDistID[1], alpha=0.2)
axsMinDist.text(0.05, 0.05, u'3.5 \u00c5, \nMinimum\nDistance', horizontalalignment='left', verticalalignment='bottom', 
                transform=axsMinDist.transAxes, fontsize='medium')


axsDist.legend(frameon=False)
axsMinDist.legend(frameon=False)

figHist.savefig('../Results/DEEM_10k/distances_3.5_random.pdf', bbox_inches='tight')
plt.show()

# %%
# Load randomly-selected DEEM and IZA histograms, 6.0 A SOAP cutoff

distDD = np.loadtxt('../Processed_Data/DEEM_1k/Histograms/6.0/Random/distAA.hist', unpack=True)
distII = np.loadtxt('../Processed_Data/DEEM_1k/Histograms/6.0/Random/distBB.hist', unpack=True)
distDI = np.loadtxt('../Processed_Data/DEEM_1k/Histograms/6.0/Random/distAB.hist', unpack=True)

minDistDD = np.loadtxt('../Processed_Data/DEEM_1k/Histograms/6.0/Random/minDistAA.hist', unpack=True)
minDistDI = np.loadtxt('../Processed_Data/DEEM_1k/Histograms/6.0/Random/minDistAB.hist', unpack=True)
minDistID = np.loadtxt('../Processed_Data/DEEM_1k/Histograms/6.0/Random/minDistBA.hist', unpack=True)

figHist = plt.figure(figsize=(3.54, 3.54))
axsDist = figHist.add_subplot(2, 1, 1)
axsMinDist = figHist.add_subplot(2, 1, 2)

for i in [axsDist, axsMinDist]:
    i.set_ylabel('Frequency')
    
axsMinDist.set_xlabel('Distance')
axsDist.set_ylim([0.0, 8.0])
axsDist.set_xlim([0.001, 1.0])
axsMinDist.set_ylim([0.0, 50.0])
axsMinDist.set_xlim([0.001, 1.0])
axsMinDist.set_xscale('log')
axsDist.set_xscale('log')

axsDist.plot(distDD[0], distDD[1], label='DEEM-DEEM')
axsDist.plot(distII[0], distII[1], label='IZA-IZA')
axsDist.plot(distDI[0], distDI[1], label='DEEM-IZA')
axsDist.fill_between(distDD[0], distDD[1], alpha=0.2)
axsDist.fill_between(distII[0], distII[1], alpha=0.2)
axsDist.fill_between(distDI[0], distDI[1], alpha=0.2)
axsDist.text(0.05, 0.05, u'6.0 \u00c5,\nDistance', horizontalalignment='left', verticalalignment='bottom', 
             transform=axsDist.transAxes, fontsize='medium')

axsMinDist.plot(minDistDD[0], minDistDD[1], label='DEEM-DEEM')
axsMinDist.plot(minDistDI[0], minDistDI[1], label='DEEM-IZA')
axsMinDist.plot(minDistID[0], minDistID[1], label='IZA-DEEM')
axsMinDist.fill_between(minDistDD[0], minDistDD[1], alpha=0.2)
axsMinDist.fill_between(minDistDI[0], minDistDI[1], alpha=0.2)
axsMinDist.fill_between(minDistID[0], minDistID[1], alpha=0.2)
axsMinDist.text(0.05, 0.05, u'6.0 \u00c5, \nMinimum Distance', horizontalalignment='left', verticalalignment='bottom', 
                transform=axsMinDist.transAxes, fontsize='medium')


axsDist.legend(frameon=False)
axsMinDist.legend(frameon=False)

figHist.savefig('../Results/DEEM_1k/distances_6.0_random.pdf', bbox_inches='tight')
plt.show()

# %%
# Load randomly-selected DEEM and IZA histograms, 6.0 A SOAP cutoff

distDD = np.loadtxt('../Processed_Data/DEEM_10k/Histograms/6.0/Random/distAA.hist', unpack=True)
distII = np.loadtxt('../Processed_Data/DEEM_10k/Histograms/6.0/Random/distBB.hist', unpack=True)
distDI = np.loadtxt('../Processed_Data/DEEM_10k/Histograms/6.0/Random/distAB.hist', unpack=True)

minDistDD = np.loadtxt('../Processed_Data/DEEM_10k/Histograms/6.0/Random/minDistAA.hist', unpack=True)
minDistDI = np.loadtxt('../Processed_Data/DEEM_10k/Histograms/6.0/Random/minDistAB.hist', unpack=True)
minDistID = np.loadtxt('../Processed_Data/DEEM_10k/Histograms/6.0/Random/minDistBA.hist', unpack=True)

figHist = plt.figure(figsize=(3.54, 3.54))
axsDist = figHist.add_subplot(2, 1, 1)
axsMinDist = figHist.add_subplot(2, 1, 2)

for i in [axsDist, axsMinDist]:
    i.set_ylabel('Frequency')
    
axsMinDist.set_xlabel('Distance')
axsDist.set_ylim([0.0, 8.0])
axsDist.set_xlim([0.001, 1.0])
axsMinDist.set_ylim([0.0, 50.0])
axsMinDist.set_xlim([0.001, 1.0])
axsMinDist.set_xscale('log')
axsDist.set_xscale('log')

axsDist.plot(distDD[0], distDD[1], label='DEEM-DEEM')
axsDist.plot(distII[0], distII[1], label='IZA-IZA')
axsDist.plot(distDI[0], distDI[1], label='DEEM-IZA')
axsDist.fill_between(distDD[0], distDD[1], alpha=0.2)
axsDist.fill_between(distII[0], distII[1], alpha=0.2)
axsDist.fill_between(distDI[0], distDI[1], alpha=0.2)
axsDist.text(0.05, 0.05, u'6.0 \u00c5,\nDistance', horizontalalignment='left', verticalalignment='bottom', 
             transform=axsDist.transAxes, fontsize='medium')

axsMinDist.plot(minDistDD[0], minDistDD[1], label='DEEM-DEEM')
axsMinDist.plot(minDistDI[0], minDistDI[1], label='DEEM-IZA')
axsMinDist.plot(minDistID[0], minDistID[1], label='IZA-DEEM')
axsMinDist.fill_between(minDistDD[0], minDistDD[1], alpha=0.2)
axsMinDist.fill_between(minDistDI[0], minDistDI[1], alpha=0.2)
axsMinDist.fill_between(minDistID[0], minDistID[1], alpha=0.2)
axsMinDist.text(0.05, 0.05, u'6.0 \u00c5, \nMinimum Distance', horizontalalignment='left', verticalalignment='bottom', 
                transform=axsMinDist.transAxes, fontsize='medium')


axsDist.legend(frameon=False)
axsMinDist.legend(frameon=False)

figHist.savefig('../Results/DEEM_10k/distances_6.0_random.pdf', bbox_inches='tight')
plt.show()
